# %%
import pandas as pd

# %%
baseline_data = pd.read_csv('spectrometer_data.txt', delimiter = '\t')

baseline_data
# Out:
#        wavelength    dark  baseline
# 0      198.913910  3567.0    3583.0
# 1      199.384414  2594.0    2614.0
# 2      199.854890  2762.0    2779.0
# 3      200.325337  2727.0    2742.0
# 4      200.795756  2772.0    2893.0
# ...           ...     ...       ...
# 2063  1109.412141  2765.0    3751.0
# 2064  1109.824415  2728.0    2734.0
# 2065  1110.236661  2734.0    2759.0
# 2066  1110.648879  2732.0    2754.0
# 2067  1111.061068  2737.0    2745.0
#
# [2068 rows x 3 columns]
